# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /home/zdim/code/kaggle_w4/.venv/lib/python3.10/site-packages (from faiss-cpu) (2.2.6)
# Requirement already satisfied: packaging in /home/zdim/code/kaggle_w4/.venv/lib/python3.10/site-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 11.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
from langchain_community.vectorstores import FAISS
from langchain_ollama import OllamaEmbeddings

FAISS_DIR = "faiss_index"
vector_store = FAISS.load_local(
    FAISS_DIR, 
    embeddings=OllamaEmbeddings(model="deepseek-r1:1.5b"), 
    allow_dangerous_deserialization=True
    )

# %%
vector_store.similarity_search("What is the work of NASA?", k=5)
# Out:
# [Document(id='1cb5d036-1c03-45c6-9c20-e3af2e5d7b5a', metadata={'source': '/home/zdim/code/kaggle_w4/backend_offline/input_documents/to_process/20210210PNAAFinal.pdf'}, page_content='Parimal Kopardekar, PhD (PK)\nDirector, NASA Aeronautics Research Institute \nParimal.H.Kopardekar@nasa.gov\nFuture Proofing \nthe Aerospace \nSupply Chain\nAerospace Supply Chain\n1'),
#  Document(id='9f455c76-d92b-4482-812b-a7304ad19d41', metadata={'source': '/home/zdim/code/kaggle_w4/backend_offline/input_documents/to_process/20210210PNAAFinal.pdf'}, page_content='Parimal Kopardekar, PhD (PK)\nDirector, NASA Aeronautics Research Institute \nParimal.H.Kopardekar@nasa.gov\nFuture Proofing \nthe Aerospace \nSupply Chain\nAerospace Supply Chain\n1'),
#  Document(id='7faf818f-4d0d-4efe-829e-84c9eaa4dc61', metadata={'source': '/home/zdim/code/kaggle_w4/backend_offline/input_documents/to_process/20210210PNAAFinal.pdf'}, page_content='Specific Steps\n•Need more suppliers to join the aerospace ecosystem \n•Reduce risks of one or few suppliers and disruptions\n•Reduce lead time by digital transformation \n•Train more manufacturing and MRO professionals \n•Access to capital –particularly lower tier suppliers \n•Tighter coordination across entire supply chain network \n5'),
#  Document(id='40598152-c594-4dca-827c-2f3258286d15', metadata={'source': '/home/zdim/code/kaggle_w4/backend_offline/input_documents/to_process/20210210PNAAFinal.pdf'}, page_content='Specific Steps\n•Need more suppliers to join the aerospace ecosystem \n•Reduce risks of one or few suppliers and disruptions\n•Reduce lead time by digital transformation \n•Train more manufacturing and MRO professionals \n•Access to capital –particularly lower tier suppliers \n•Tighter coordination across entire supply chain network \n5'),
#  Document(id='6cfc682c-ecfe-465d-853c-736b2a93fac2', metadata={'source': '/home/zdim/code/kaggle_w4/backend_offline/input_documents/to_process/20210210PNAAFinal.pdf'}, page_content='Needs Assessment from New Entrants\n2\nMany calls, texts, and \ninteractions about looking \nfor suppliers and \nmanufacturers\n•Over -molding\n•Actuators\n•Electric motors\n•Propellers\n•Casting\n•Many other components and \nmanufacturing needs\nAerospace Needs \nSustainable Supplier, \nManufacturer, and MRO \nNetwork')]
